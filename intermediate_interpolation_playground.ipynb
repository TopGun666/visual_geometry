# %%
import cv2
import glob
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

import seaborn as sns

from sklearn.neural_network import MLPRegressor

from mystic.penalty import quadratic_inequality
from mystic.solvers import diffev2
from mystic.monitors import VerboseMonitor

from src.camera import Camera
from src.utils.cube import generate_cube, draw_cube
from src.utils.functions import window
from src.utils.reprojection import reprojection_distance

# %%
class Frame(object):
    """ Frame object that stores all possible information needed """
    MATCHER_THREHSOLD = 0.55
    
    def __init__(self, image):
        self.image = np.copy(image)
        self.R = np.array([])
        self.t = np.array([])
        self.points_3d = np.array([])
        self.points_2d = np.array([])
        self.kp = np.array([])
        self.des = np.array([])
        
    def __str__(self):
        return "Frame:\n>> R:{}\n>> t:{}\n>> 3D:{}\n>> 2D:{}\n>> kp:{}\n>> des:{}\n".format(
            self.R.shape,
            self.t.shape,
            self.points_3d.shape,
            self.points_2d.shape,
            len(self.kp),
            len(self.des)
        )

    def create_camera_and_project(self, obj):
        camera = Camera.create(self.R, self.t)
        return camera.project(obj)
    
    def bundle_adjustment(self):
        """ Bundle adjust frame """

        R = cv2.Rodrigues(self.R)[0]
        t = self.t
        initial = [R[0], R[1], R[2], t[0], t[1], t[2]]
        initial = [x[0] for x in initial]
        
        mon = VerboseMonitor(100)
        result = diffev2(
            reprojection_distance, 
            x0=initial, 
            args=(self.points_3d, self.points_2d),
            npop=10, 
            gtol=200,
            disp=False, 
            full_output=True, 
            itermon=mon, 
            maxiter=1000
        )
        
        result = result[0] #optimized.x
        r1, r2, r3, t1, t2, t3 = result[0], result[1], result[2], result[3], result[4], result[5]

        R_optimized = cv2.Rodrigues(np.array([r1, r2, r3]))[0]
        t_optimized = np.array([[t1], [t2], [t3]])
        
        optimized_frame = Frame(self.image)
        optimized_frame.R = R_optimized
        optimized_frame.t = t_optimized
        optimized_frame.points_3d = self.points_3d
        optimized_frame.points_2d = self.points_2d
        optimized_frame.kp = self.kp
        optimized_frame.des = self.des
        
        return optimized_frame

# %%
class Scene(object):
    """ Scene utils """
    @classmethod
    def get_rt_from_essential(cls, pts1, pts2):
        E, mask = cv2.findEssentialMat(
            pts1, 
            pts2, 
            focal=1.0, 
            pp=(486.2, 265.59), 
            method=cv2.RANSAC, 
            prob=0.999, 
            threshold=1.0
        )

        points, R, t, mask = cv2.recoverPose(
            E, 
            pts1, 
            pts2, 
            focal=1.0,
            pp=(486.2, 265.59),
            mask=mask
        )
        
        return R, t
    
    
    @classmethod
    def recover_third_rt(cls, pts1, camera1, pts2, camera2, pts3):
        K, dist = Camera().K, Camera().distortion 
        undistorted_points_1 = cv2.undistortPoints(pts1, K, dist, R=camera1.R, P=camera1.get_projection_matrix())
        undistorted_points_2 = cv2.undistortPoints(pts2, K, dist, R=camera2.R, P=camera2.get_projection_matrix())

        points_3d_homog = cv2.triangulatePoints(
            camera1.get_projection_matrix(),
            camera2.get_projection_matrix(),
            undistorted_points_1,
            undistorted_points_2
        )
        points_3d = cv2.convertPointsFromHomogeneous(points_3d_homog.T)
                
        _, rvecs, tvecs, inliers = cv2.solvePnPRansac(points_3d, pts3, Camera().K, Camera().distortion) 
        return cv2.Rodrigues(rvecs)[0], tvecs, points_3d
    
    @classmethod
    def initial_triangulation(cls, image1, image2, image3):
        """ 1. Initial stereo camera reconstruction
            2. Third camera triangulation
        """
        sift = cv2.xfeatures2d.SIFT_create()
        FLANN_INDEX_KDTREE = 0
        index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = 5)
        search_params = dict(checks = 50)
        flann = cv2.FlannBasedMatcher(index_params, search_params)

        kp1, des1 = sift.detectAndCompute(image1, None)
        kp2, des2 = sift.detectAndCompute(image2, None)
        kp3, des3 = sift.detectAndCompute(image3, None)

        matches12 = flann.knnMatch(des1, des2, k=2)
        matches13 = flann.knnMatch(des1, des3, k=2)

        qidx12 = [m.queryIdx for m,n in list(filter(lambda x: x[0].distance < Frame.MATCHER_THREHSOLD*x[1].distance, matches12))]
        qidx13 = [m.queryIdx for m,n in list(filter(lambda x: x[0].distance < Frame.MATCHER_THREHSOLD*x[1].distance, matches13))]

        common_query_indexes = list(set(qidx12).intersection(qidx13))

        # match between 3 images
        good_12_matches = []
        for m, n in matches12:
            if m.queryIdx in common_query_indexes:
                good_12_matches.append(m)

        good_13_matches = []
        for m, n in matches13:
            if m.queryIdx in common_query_indexes:
                good_13_matches.append(m)

        pts1 = np.float64([kp1[m.queryIdx].pt for m in good_12_matches]).reshape(-1,1,2)
        pts2 = np.float64([kp2[m.trainIdx].pt for m in good_12_matches]).reshape(-1,1,2)
        pts3 = np.float64([kp3[m.trainIdx].pt for m in good_13_matches]).reshape(-1,1,2)
        
        R2, t2 = Scene.get_rt_from_essential(pts1, pts2)
            
        camera1 = Camera.create(np.eye(3, 3), np.zeros((3, 1)))
        camera2 = Camera.create(R2, t2)
        
        R3, t3, points_3d = Scene.recover_third_rt(camera1=camera1, camera2=camera2, pts1=pts1, pts2=pts2, pts3=pts3)

        frame1 = Frame(image1)
        frame1.R = camera1.R
        frame1.t = camera1.t
        frame1.points_3d = points_3d
        frame1.points_2d = pts1
        frame1.kp = kp1
        frame1.des = des1
        
        frame2 = Frame(image2)
        frame2.R = camera2.R
        frame2.t = camera2.t
        frame2.points_3d = points_3d
        frame2.points_2d = pts2
        frame2.kp = kp2
        frame2.des = des2
        
        frame3 = Frame(image3)
        frame3.R = R3
        frame3.t = t3
        frame3.points_3d = points_3d
        frame3.points_2d = pts3
        frame3.kp = kp3
        frame3.des = des3
        
        return frame1, frame2, frame3
    
    @classmethod
    def triangulation(cls, frame1, frame2, image3):
        """ 1. Stereo camera reconstruction
            2. Third camera triangulation
        """
        
        sift = cv2.xfeatures2d.SIFT_create()
        FLANN_INDEX_KDTREE = 0
        index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = 5)
        search_params = dict(checks = 50)
        flann = cv2.FlannBasedMatcher(index_params, search_params)

        kp1, des1 = sift.detectAndCompute(frame1.image, None)
        kp2, des2 = sift.detectAndCompute(frame2.image, None)
        kp3, des3 = sift.detectAndCompute(image3, None)

        matches12 = flann.knnMatch(des1, des2, k=2)
        matches13 = flann.knnMatch(des1, des3, k=2)

        qidx12 = [m.queryIdx for m,n in list(filter(lambda x: x[0].distance < Frame.MATCHER_THREHSOLD*x[1].distance, matches12))]
        qidx13 = [m.queryIdx for m,n in list(filter(lambda x: x[0].distance < Frame.MATCHER_THREHSOLD*x[1].distance, matches13))]

        common_query_indexes = list(set(qidx12).intersection(qidx13))

        # match between 3 images
        good_12_matches = []
        for m, n in matches12:
            if m.queryIdx in common_query_indexes:
                good_12_matches.append(m)

        good_13_matches = []
        for m, n in matches13:
            if m.queryIdx in common_query_indexes:
                good_13_matches.append(m)

        pts1 = np.float64([kp1[m.queryIdx].pt for m in good_12_matches]).reshape(-1,1,2)
        pts2 = np.float64([kp2[m.trainIdx].pt for m in good_12_matches]).reshape(-1,1,2)
        pts3 = np.float64([kp3[m.trainIdx].pt for m in good_13_matches]).reshape(-1,1,2)
                    
        camera1 = Camera.create(frame1.R, frame1.t)
        camera2 = Camera.create(frame2.R, frame2.t)
        
        R3, t3, points_3d = Scene.recover_third_rt(camera1=camera1, camera2=camera2, pts1=pts1, pts2=pts2, pts3=pts3)
        
        frame3 = Frame(image3)
        frame3.R = R3
        frame3.t = t3
        frame3.points_3d = points_3d
        frame3.points_2d = pts3
        frame3.kp = kp3
        frame3.des = des3
        
        return frame1, frame2, frame3

# %%
class Timeline(object):
    """ Main class that stores video """
    RESIZE_SCALE = 2
    KEYFRAME_DISTANCE = 50
    
    def __init__(self, path="videos/video13.mp4"):
        self.path_video = path # path to video
        self.buffer = [] # buffered video a.k.a images
        self.K = Camera().K # calibration matrix
        self.distortion = Camera().distortion # distortion coefs
        self.common_points = [] # common points between keyframes    
        
        self.__read_into_buffer()
        self.keyframes_indexes = [x for x in range(0, len(self.buffer), self.KEYFRAME_DISTANCE)]
        
        self.keyframes = []
        self.adjusted_keyframes = []
        self.__recover_keyframes()
        self.__adjust_keyframes()
        self.interpolated_frames = []

        print("Timeline initialized...")
        
        
    def __resize(self, frame):
        """ Resize video in hald """
        height, width, layers =  frame.shape
        frame = cv2.resize(frame, (int(width/2), int(height/2)))
        return frame
        
    def __read_into_buffer(self, mode="pictures"):
        """ Reads video/images into object buffer """
        buffer = []

        print("Buffering: start...")
        if mode == "pictures":
            print("Reading from images sequence in frames folder...")
            for path in glob.glob("frames/**.png"):
                img = cv2.imread(path)
                buffer.append(img)
        else:
            print("Reading from video file {}...".format(self.path_video))
            cap = cv2.VideoCapture(self.path_video)
            original_images_buffer = []
            while(cap.isOpened()):
                ret, frame = cap.read()    
                if ret == True:
                    frame = self.__resize(frame)
                    buffer.append(frame)
                    original_images_buffer.append(frame)
                else:
                    cap.release()
                
        self.buffer = buffer
        print("Buffering: done")
                
    def __recover_keyframes(self):
        """ Recover keyframes based on number of keyframe triple.
        If first that recover via singular rotation matrix and calculating essential matrix
        """
        print("Keyframes recovering: start...")
        keyframes = []
        frame1, frame2, frame3 = None, None, None
        
        for i, triple in enumerate(window(self.keyframes_indexes, 3)):
            image1, image2, image3 = self.buffer[triple[0]], self.buffer[triple[1]], self.buffer[triple[2]]
            if i > 0:
                frame1, frame2, frame3 = Scene.triangulation(frame1, frame3, image3)
                keyframes.append(frame3)
            else: # if initial
                frame1, frame2, frame3 = Scene.initial_triangulation(image1, image2, image3)
                keyframes = [frame1, frame2, frame3]
                
        self.keyframes = keyframes
        print("Keyframes recovering: done")
                
    def __adjust_keyframes(self):
        print("Keyframe bundle adjustment: start...")
        self.adjusted_keyframes = [frame.bundle_adjustment() for frame in self.keyframes[:]]
        print("Keyframe bundle adjustment: done")

    def interpolate_frames_and_save(self):
        print("Intermediate frames interpolation: start...")
        print("WARNING: this operation take a lot of time... (over 20 minutes)")
        intermediate_frames = []
        for i, (kf1, kf2, kf3) in enumerate(window(self.adjusted_keyframes, 3)):
            print("Step", i)
            if i == 0:
                intermediate_images = self.buffer[i*self.KEYFRAME_DISTANCE:(i+2)*self.KEYFRAME_DISTANCE]
            else:
                intermediate_images = self.buffer[(i+1)*self.KEYFRAME_DISTANCE:(i+2)*self.KEYFRAME_DISTANCE]
            for intermediate_image in intermediate_images:
                intermediate_frame = Scene.triangulation(kf1, kf3, intermediate_image)[2]
                intermediate_frames.append(intermediate_frame)
                
        adjusted_intermediate_frames = [f.bundle_adjustment() for f in intermediate_frames[:100]]
        
        for i, aiframe in enumerate(adjusted_intermediate_frames):
            frame = Frame(aiframe.image)
            try:
                image = draw_cube(frame.image, aiframe.create_camera_and_project(cube), wide=2)
                cv2.imwrite("saved_images/{}.png".format("%03d" % i), image)
            except Exception as e:
                print(e)
        
        self.interpolated_frames = adjusted_intermediate_frames
        print("Intermediate frames interpolation: done")
        
    def interpolate_frames_by_network_and_save(self):
        print("Intermediate frames interpolation by nnet: start...")
        cube = generate_cube(1.0, [0,0,10])
        train = []
        for kf in self.adjusted_keyframes[:]:
            object_points = []
            for point in kf.create_camera_and_project(cube):
                x, y = point[0]
                object_points.append(x)
                object_points.append(y)

            train.append(object_points)

        df = pd.DataFrame(train)
        
        X = np.array([x*self.KEYFRAME_DISTANCE for x in range(df.shape[0])]).reshape(df.shape[0], 1)
        y = df
        
        print("Nnet training: start...")
        mlp = MLPRegressor(
            max_iter=2000,
            learning_rate_init=0.01,
            random_state=42
        )
        mlp.fit(X, y)
        print("Nnet:", mlp)
        print("Nnet training: done")
        
        print("Saving images: start...")
        for i, image in enumerate(self.buffer[:120]):
            frame = Frame(image)
            res = mlp.predict(i)
            image = draw_cube(frame.image, res.reshape((-1, 1, 2)))

            cv2.imwrite("saved_images/{}.png".format("%03d" % i), image)
        
        print("Intermediate frames interpolation: done")
        print("Saving images: done")

# %%
timeline = Timeline()
# Out:
# Buffering: start...
# Reading from images sequence in frames folder...
# Buffering: done
# Keyframes recovering: start...
# (55, 1, 3) (55, 1, 2)
# (12, 1, 3) (12, 1, 2)
# Keyframes recovering: done
# Keyframe bundle adjustment: start...
# Generation 0 has Chi-Squared: 3373.808870
# Generation 100 has Chi-Squared: 403.835055
# Generation 200 has Chi-Squared: 389.364335
# Generation 300 has Chi-Squared: 387.701874
# Generation 400 has Chi-Squared: 387.601055
# Generation 500 has Chi-Squared: 387.593396
# Generation 600 has Chi-Squared: 387.592184
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 12060.855976
# Generation 100 has Chi-Squared: 1325.277896
# Generation 200 has Chi-Squared: 887.428897
# Generation 300 has Chi-Squared: 474.878800
# Generation 400 has Chi-Squared: 459.154460
# Generation 500 has Chi-Squared: 457.134655
# Generation 600 has Chi-Squared: 455.926738
# Generation 700 has Chi-Squared: 453.490933
# Generation 800 has Chi-Squared: 449.842492
# Generation 900 has Chi-Squared: 449.700654
# Generation 1000 has Chi-Squared: 449.601815
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 74504.510988
# Generation 100 has Chi-Squared: 23156.880341
# Generation 200 has Chi-Squared: 16117.115559
# Generation 300 has Chi-Squared: 12190.460620
# Generation 400 has Chi-Squared: 9293.825025
# Generation 500 has Chi-Squared: 9194.784856
# Generation 600 has Chi-Squared: 9194.447683
# Generation 700 has Chi-Squared: 9194.324610
# Generation 800 has Chi-Squared: 9194.314631
# Generation 900 has Chi-Squared: 9194.283707
# Generation 1000 has Chi-Squared: 9194.086487
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 23589.494545
# Generation 100 has Chi-Squared: 4573.818408
# Generation 200 has Chi-Squared: 4435.886199
# Generation 300 has Chi-Squared: 4406.865660
# Generation 400 has Chi-Squared: 4394.181823
# Generation 500 has Chi-Squared: 4393.711611
# Generation 600 has Chi-Squared: 4391.684416
# Generation 700 has Chi-Squared: 4390.920738
# Generation 800 has Chi-Squared: 4390.608770
# Generation 900 has Chi-Squared: 4390.413382
# Generation 1000 has Chi-Squared: 4390.279722
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Keyframe bundle adjustment: done
# Timeline initialized...

# %%
cube = generate_cube(1.0, [0,0,10])

# %%
intermediate_frames = []
for i, (kf1, kf2, kf3) in enumerate(window(timeline.adjusted_keyframes, 3)):
    print("Step", i)
    if i == 0:
        intermediate_images = timeline.buffer[i*timeline.KEYFRAME_DISTANCE:(i+2)*timeline.KEYFRAME_DISTANCE]
    else:
        intermediate_images = timeline.buffer[(i+1)*timeline.KEYFRAME_DISTANCE:(i+2)*timeline.KEYFRAME_DISTANCE]
    for intermediate_image in intermediate_images:
        intermediate_frame = Scene.triangulation(kf1, kf3, intermediate_image)[2]
        intermediate_frames.append(intermediate_frame)
# Out:
# Step 0
# Step 1

# %%
for i, iframe in enumerate(intermediate_frames):
    frame = Frame(iframe.image)
    try:
        image = draw_cube(frame.image, iframe.create_camera_and_project(cube), wide=2)
        cv2.imwrite("intermediate/{}.png".format("%03d" % i), image)
    except Exception as e:
        print(e)

# %%
# it is gonna last forever!
adjusted_intermediate_frames = [f.bundle_adjustment() for f in intermediate_frames[:100]]
# Out:
# Generation 0 has Chi-Squared: 54343.152999
# Generation 100 has Chi-Squared: 5786.314797
# Generation 200 has Chi-Squared: 5566.887863
# Generation 300 has Chi-Squared: 5566.167581
# Generation 400 has Chi-Squared: 5564.168781
# Generation 500 has Chi-Squared: 5564.060291
# Generation 600 has Chi-Squared: 5562.839904
# Generation 700 has Chi-Squared: 5562.484621
# Generation 800 has Chi-Squared: 5562.434227
# Generation 900 has Chi-Squared: 5562.423741
# Generation 1000 has Chi-Squared: 5562.423672
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 46675.649554
# Generation 100 has Chi-Squared: 5270.868163
# Generation 200 has Chi-Squared: 4298.842155
# Generation 300 has Chi-Squared: 4080.048965
# Generation 400 has Chi-Squared: 3952.850708
# Generation 500 has Chi-Squared: 3899.689976
# Generation 600 has Chi-Squared: 3897.854865
# Generation 700 has Chi-Squared: 3897.851459
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 42078.689301
# Generation 100 has Chi-Squared: 4635.276388
# Generation 200 has Chi-Squared: 4524.443846
# Generation 300 has Chi-Squared: 4511.508941
# Generation 400 has Chi-Squared: 4511.484754
# Generation 500 has Chi-Squared: 4511.478134
# Generation 600 has Chi-Squared: 4511.476012
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 41927.781231
# Generation 100 has Chi-Squared: 4901.282295
# Generation 200 has Chi-Squared: 4370.192122
# Generation 300 has Chi-Squared: 4189.845728
# Generation 400 has Chi-Squared: 4186.452217
# Generation 500 has Chi-Squared: 4186.411509
# Generation 600 has Chi-Squared: 4186.388599
# Generation 700 has Chi-Squared: 4186.337859
# Generation 800 has Chi-Squared: 4186.324962
# Generation 900 has Chi-Squared: 4185.719760
# Generation 1000 has Chi-Squared: 4185.547025
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 26460.862477
# Generation 100 has Chi-Squared: 5313.737888
# Generation 200 has Chi-Squared: 4085.930381
# Generation 300 has Chi-Squared: 3892.725330
# Generation 400 has Chi-Squared: 3729.088813
# Generation 500 has Chi-Squared: 3646.282450
# Generation 600 has Chi-Squared: 3544.482633
# Generation 700 has Chi-Squared: 3543.431617
# Generation 800 has Chi-Squared: 3535.713987
# Generation 900 has Chi-Squared: 3518.492095
# Generation 1000 has Chi-Squared: 3518.458488
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 20830.908861
# Generation 100 has Chi-Squared: 9963.283729
# Generation 200 has Chi-Squared: 9653.137937
# Generation 300 has Chi-Squared: 3485.643758
# Generation 400 has Chi-Squared: 3157.469230
# Generation 500 has Chi-Squared: 3153.880196
# Generation 600 has Chi-Squared: 3153.535278
# Generation 700 has Chi-Squared: 3153.515275
# Generation 800 has Chi-Squared: 3153.514816
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 35066.412294
# Generation 100 has Chi-Squared: 2796.181543
# Generation 200 has Chi-Squared: 2617.172751
# Generation 300 has Chi-Squared: 2515.299650
# Generation 400 has Chi-Squared: 2434.348433
# Generation 500 has Chi-Squared: 2422.615952
# Generation 600 has Chi-Squared: 2422.615293
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 32202.270868
# Generation 100 has Chi-Squared: 7006.664978
# Generation 200 has Chi-Squared: 3576.306387
# Generation 300 has Chi-Squared: 3457.181663
# Generation 400 has Chi-Squared: 3456.919139
# Generation 500 has Chi-Squared: 3456.035791
# Generation 600 has Chi-Squared: 3456.004225
# Generation 700 has Chi-Squared: 3456.004036
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 2593.585262
# Generation 100 has Chi-Squared: 2440.930623
# Generation 200 has Chi-Squared: 2407.794331
# Generation 300 has Chi-Squared: 2399.371165
# Generation 400 has Chi-Squared: 2399.180904
# Generation 500 has Chi-Squared: 2399.093274
# Generation 600 has Chi-Squared: 2399.093225
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 29113.717240
# Generation 100 has Chi-Squared: 13171.524623
# Generation 200 has Chi-Squared: 8787.474213
# Generation 300 has Chi-Squared: 2745.400872
# Generation 400 has Chi-Squared: 2676.641909
# Generation 500 has Chi-Squared: 2637.004821
# Generation 600 has Chi-Squared: 2614.404517
# Generation 700 has Chi-Squared: 2613.877617
# Generation 800 has Chi-Squared: 2613.854050
# Generation 900 has Chi-Squared: 2613.850873
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 23096.364885
# Generation 100 has Chi-Squared: 8562.350889
# Generation 200 has Chi-Squared: 2534.793142
# Generation 300 has Chi-Squared: 2199.271160
# Generation 400 has Chi-Squared: 2069.960173
# Generation 500 has Chi-Squared: 2062.547137
# Generation 600 has Chi-Squared: 2038.525929
# Generation 700 has Chi-Squared: 1948.768717
# Generation 800 has Chi-Squared: 1946.553269
# Generation 900 has Chi-Squared: 1936.082486
# Generation 1000 has Chi-Squared: 1931.835608
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 26252.021211
# Generation 100 has Chi-Squared: 2407.828098
# Generation 200 has Chi-Squared: 2319.170463
# Generation 300 has Chi-Squared: 2317.375904
# Generation 400 has Chi-Squared: 2317.010720
# Generation 500 has Chi-Squared: 2317.000973
# Generation 600 has Chi-Squared: 2317.000747
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 29443.622534
# Generation 100 has Chi-Squared: 5097.323628
# Generation 200 has Chi-Squared: 2733.678346
# Generation 300 has Chi-Squared: 2676.615130
# Generation 400 has Chi-Squared: 2659.585849
# Generation 500 has Chi-Squared: 2657.058361
# Generation 600 has Chi-Squared: 2656.802071
# Generation 700 has Chi-Squared: 2656.802071
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 3264.767733
# Generation 100 has Chi-Squared: 2668.209225
# Generation 200 has Chi-Squared: 2668.209222
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 3877.542659
# Generation 100 has Chi-Squared: 2872.919365
# Generation 200 has Chi-Squared: 2870.241566
# Generation 300 has Chi-Squared: 2866.531820
# Generation 400 has Chi-Squared: 2648.407394
# Generation 500 has Chi-Squared: 2529.712493
# Generation 600 has Chi-Squared: 2528.637399
# Generation 700 has Chi-Squared: 2528.339314
# Generation 800 has Chi-Squared: 2528.325972
# Generation 900 has Chi-Squared: 2528.260005
# Generation 1000 has Chi-Squared: 2528.245781
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 19143.546167
# Generation 100 has Chi-Squared: 3708.788329
# Generation 200 has Chi-Squared: 3194.959179
# Generation 300 has Chi-Squared: 3193.990617
# Generation 400 has Chi-Squared: 3193.082295
# Generation 500 has Chi-Squared: 3192.878276
# Generation 600 has Chi-Squared: 3192.809955
# Generation 700 has Chi-Squared: 3192.805616
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 27397.744090
# Generation 100 has Chi-Squared: 3905.756149
# Generation 200 has Chi-Squared: 3477.729168
# Generation 300 has Chi-Squared: 3307.661260
# Generation 400 has Chi-Squared: 3134.373968
# Generation 500 has Chi-Squared: 3002.375205
# Generation 600 has Chi-Squared: 2942.050079
# Generation 700 has Chi-Squared: 2932.668465
# Generation 800 has Chi-Squared: 2929.617351
# Generation 900 has Chi-Squared: 2928.181196
# Generation 1000 has Chi-Squared: 2927.874019
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 4434.344808
# Generation 100 has Chi-Squared: 2607.661941
# Generation 200 has Chi-Squared: 2564.767421
# Generation 300 has Chi-Squared: 2563.341932
# Generation 400 has Chi-Squared: 2563.152111
# Generation 500 has Chi-Squared: 2563.149487
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 23971.685703
# Generation 100 has Chi-Squared: 4335.724772
# Generation 200 has Chi-Squared: 4335.724772
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 20824.472804
# Generation 100 has Chi-Squared: 3191.572542
# Generation 200 has Chi-Squared: 2902.153841
# Generation 300 has Chi-Squared: 2855.934070
# Generation 400 has Chi-Squared: 2714.408719
# Generation 500 has Chi-Squared: 2700.013087
# Generation 600 has Chi-Squared: 2699.663689
# Generation 700 has Chi-Squared: 2699.651150
# Generation 800 has Chi-Squared: 2699.650856
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 2096.743696
# Generation 100 has Chi-Squared: 1929.171886
# Generation 200 has Chi-Squared: 1926.346236
# Generation 300 has Chi-Squared: 1925.640082
# Generation 400 has Chi-Squared: 1925.633815
# Generation 500 has Chi-Squared: 1925.632476
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 14270.176699
# Generation 100 has Chi-Squared: 7668.046029
# Generation 200 has Chi-Squared: 2207.795547
# Generation 300 has Chi-Squared: 2188.374019
# Generation 400 has Chi-Squared: 2188.368712
# Generation 500 has Chi-Squared: 2188.368712
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 10040.553770
# Generation 100 has Chi-Squared: 1705.773135
# Generation 200 has Chi-Squared: 1580.090827
# Generation 300 has Chi-Squared: 1573.313323
# Generation 400 has Chi-Squared: 1568.019742
# Generation 500 has Chi-Squared: 1563.301849
# Generation 600 has Chi-Squared: 1562.514973
# Generation 700 has Chi-Squared: 1562.473710
# Generation 800 has Chi-Squared: 1562.473619
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 5641.725288
# Generation 100 has Chi-Squared: 1920.029293
# Generation 200 has Chi-Squared: 1674.931569
# Generation 300 has Chi-Squared: 1667.892603
# Generation 400 has Chi-Squared: 1666.794416
# Generation 500 has Chi-Squared: 1666.766894
# Generation 600 has Chi-Squared: 1666.766314
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 9031.005557
# Generation 100 has Chi-Squared: 4031.017711
# Generation 200 has Chi-Squared: 2278.859059
# Generation 300 has Chi-Squared: 2004.622725
# Generation 400 has Chi-Squared: 2001.793696
# Generation 500 has Chi-Squared: 2000.984818
# Generation 600 has Chi-Squared: 2000.852424
# Generation 700 has Chi-Squared: 2000.824135
# Generation 800 has Chi-Squared: 2000.790585
# Generation 900 has Chi-Squared: 2000.778051
# Generation 1000 has Chi-Squared: 2000.774742
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 14749.160132
# Generation 100 has Chi-Squared: 2053.657513
# Generation 200 has Chi-Squared: 1956.229776
# Generation 300 has Chi-Squared: 1943.328376
# Generation 400 has Chi-Squared: 1939.960591
# Generation 500 has Chi-Squared: 1939.567476
# Generation 600 has Chi-Squared: 1939.318942
# Generation 700 has Chi-Squared: 1938.684519
# Generation 800 has Chi-Squared: 1938.595661
# Generation 900 has Chi-Squared: 1938.595557
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 1647.516585
# Generation 100 has Chi-Squared: 1464.850624
# Generation 200 has Chi-Squared: 1464.084371
# Generation 300 has Chi-Squared: 1463.898820
# Generation 400 has Chi-Squared: 1463.842180
# Generation 500 has Chi-Squared: 1463.839888
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 6267.986468
# Generation 100 has Chi-Squared: 1918.482098
# Generation 200 has Chi-Squared: 1803.407003
# Generation 300 has Chi-Squared: 1786.052545
# Generation 400 has Chi-Squared: 1719.255966
# Generation 500 has Chi-Squared: 1649.764772
# Generation 600 has Chi-Squared: 1649.527391
# Generation 700 has Chi-Squared: 1649.509696
# Generation 800 has Chi-Squared: 1649.508576
# Generation 900 has Chi-Squared: 1649.503911
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 9392.939591
# Generation 100 has Chi-Squared: 1321.106701
# Generation 200 has Chi-Squared: 1278.331044
# Generation 300 has Chi-Squared: 1277.917162
# Generation 400 has Chi-Squared: 1277.912074
# Generation 500 has Chi-Squared: 1277.909868
# Generation 600 has Chi-Squared: 1277.904102
# Generation 700 has Chi-Squared: 1277.903387
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 5950.592079
# Generation 100 has Chi-Squared: 1395.337466
# Generation 200 has Chi-Squared: 1056.502618
# Generation 300 has Chi-Squared: 1031.202331
# Generation 400 has Chi-Squared: 1026.362919
# Generation 500 has Chi-Squared: 1026.129489
# Generation 600 has Chi-Squared: 1026.123007
# Generation 700 has Chi-Squared: 1026.121805
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 8650.921574
# Generation 100 has Chi-Squared: 1615.976973
# Generation 200 has Chi-Squared: 1613.411773
# Generation 300 has Chi-Squared: 1613.208229
# Generation 400 has Chi-Squared: 1613.139029
# Generation 500 has Chi-Squared: 1612.986993
# Generation 600 has Chi-Squared: 1612.969725
# Generation 700 has Chi-Squared: 1612.969318
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 1561.837193
# Generation 100 has Chi-Squared: 1333.945039
# Generation 200 has Chi-Squared: 1333.657115
# Generation 300 has Chi-Squared: 1333.555244
# Generation 400 has Chi-Squared: 1333.529192
# Generation 500 has Chi-Squared: 1333.491354
# Generation 600 has Chi-Squared: 1333.491309
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 14551.988943
# Generation 100 has Chi-Squared: 1422.123625
# Generation 200 has Chi-Squared: 1419.447724
# Generation 300 has Chi-Squared: 1419.419248
# Generation 400 has Chi-Squared: 1419.411782
# Generation 500 has Chi-Squared: 1419.411763
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 2199.517161
# Generation 100 has Chi-Squared: 1546.178662
# Generation 200 has Chi-Squared: 1531.828353
# Generation 300 has Chi-Squared: 1529.903759
# Generation 400 has Chi-Squared: 1528.941316
# Generation 500 has Chi-Squared: 1527.690122
# Generation 600 has Chi-Squared: 1527.601292
# Generation 700 has Chi-Squared: 1527.592125
# Generation 800 has Chi-Squared: 1527.592076
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 11240.180945
# Generation 100 has Chi-Squared: 1881.930722
# Generation 200 has Chi-Squared: 1715.230714
# Generation 300 has Chi-Squared: 1585.596031
# Generation 400 has Chi-Squared: 1554.753795
# Generation 500 has Chi-Squared: 1554.588439
# Generation 600 has Chi-Squared: 1554.566753
# Generation 700 has Chi-Squared: 1554.546642
# Generation 800 has Chi-Squared: 1554.218133
# Generation 900 has Chi-Squared: 1554.073571
# Generation 1000 has Chi-Squared: 1554.010925
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 13491.438413
# Generation 100 has Chi-Squared: 2285.418044
# Generation 200 has Chi-Squared: 1721.816795
# Generation 300 has Chi-Squared: 1656.868871
# Generation 400 has Chi-Squared: 1644.664456
# Generation 500 has Chi-Squared: 1642.703438
# Generation 600 has Chi-Squared: 1642.662057
# Generation 700 has Chi-Squared: 1642.645599
# Generation 800 has Chi-Squared: 1642.645553
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 5802.463209
# Generation 100 has Chi-Squared: 1787.228941
# Generation 200 has Chi-Squared: 1568.353768
# Generation 300 has Chi-Squared: 1490.948636
# Generation 400 has Chi-Squared: 1457.277395
# Generation 500 has Chi-Squared: 1446.562237
# Generation 600 has Chi-Squared: 1443.011922
# Generation 700 has Chi-Squared: 1440.077426
# Generation 800 has Chi-Squared: 1432.007944
# Generation 900 has Chi-Squared: 1428.745847
# Generation 1000 has Chi-Squared: 1428.600448
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 1324.180329
# Generation 100 has Chi-Squared: 1054.241062
# Generation 200 has Chi-Squared: 1054.236628
# Generation 300 has Chi-Squared: 1054.231868
# Generation 400 has Chi-Squared: 1054.228709
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 7521.174974
# Generation 100 has Chi-Squared: 1366.300628
# Generation 200 has Chi-Squared: 1365.907438
# Generation 300 has Chi-Squared: 1365.902326
# Generation 400 has Chi-Squared: 1365.899834
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 9377.870733
# Generation 100 has Chi-Squared: 1185.179546
# Generation 200 has Chi-Squared: 1133.513734
# Generation 300 has Chi-Squared: 1126.195465
# Generation 400 has Chi-Squared: 1123.838791
# Generation 500 has Chi-Squared: 1119.137169
# Generation 600 has Chi-Squared: 1110.951101
# Generation 700 has Chi-Squared: 1110.520895
# Generation 800 has Chi-Squared: 1110.281149
# Generation 900 has Chi-Squared: 1110.241176
# Generation 1000 has Chi-Squared: 1110.237113
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 1825.689453
# Generation 100 has Chi-Squared: 1023.662243
# Generation 200 has Chi-Squared: 1010.681588
# Generation 300 has Chi-Squared: 1005.516087
# Generation 400 has Chi-Squared: 1005.037459
# Generation 500 has Chi-Squared: 1004.792051
# Generation 600 has Chi-Squared: 1004.644171
# Generation 700 has Chi-Squared: 1004.610443
# Generation 800 has Chi-Squared: 1004.606028
# Generation 900 has Chi-Squared: 1004.602446
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 1241.115393
# Generation 100 has Chi-Squared: 962.726690
# Generation 200 has Chi-Squared: 900.097971
# Generation 300 has Chi-Squared: 889.560377
# Generation 400 has Chi-Squared: 889.248630
# Generation 500 has Chi-Squared: 889.150754
# Generation 600 has Chi-Squared: 888.840713
# Generation 700 has Chi-Squared: 888.783920
# Generation 800 has Chi-Squared: 888.759857
# Generation 900 has Chi-Squared: 888.750054
# Generation 1000 has Chi-Squared: 888.747585
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 3665.132515
# Generation 100 has Chi-Squared: 1022.833682
# Generation 200 has Chi-Squared: 840.137474
# Generation 300 has Chi-Squared: 837.201336
# Generation 400 has Chi-Squared: 836.410215
# Generation 500 has Chi-Squared: 836.332019
# Generation 600 has Chi-Squared: 836.329193
# Generation 700 has Chi-Squared: 836.326553
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 890.962996
# Generation 100 has Chi-Squared: 756.487880
# Generation 200 has Chi-Squared: 702.766165
# Generation 300 has Chi-Squared: 702.500560
# Generation 400 has Chi-Squared: 702.298468
# Generation 500 has Chi-Squared: 702.272874
# Generation 600 has Chi-Squared: 702.269475
# Generation 700 has Chi-Squared: 702.265284
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 1949.686600
# Generation 100 has Chi-Squared: 657.731808
# Generation 200 has Chi-Squared: 589.845079
# Generation 300 has Chi-Squared: 589.378114
# Generation 400 has Chi-Squared: 589.297338
# Generation 500 has Chi-Squared: 589.239022
# Generation 600 has Chi-Squared: 589.219941
# Generation 700 has Chi-Squared: 589.218475
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 2747.294137
# Generation 100 has Chi-Squared: 538.148594
# Generation 200 has Chi-Squared: 534.309867
# Generation 300 has Chi-Squared: 534.263697
# Generation 400 has Chi-Squared: 534.252367
# Generation 500 has Chi-Squared: 534.250398
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 746.740040
# Generation 100 has Chi-Squared: 519.313558
# Generation 200 has Chi-Squared: 519.303803
# Generation 300 has Chi-Squared: 519.303657
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 443.930251
# Generation 100 has Chi-Squared: 443.930251
# Generation 200 has Chi-Squared: 443.930251
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 868.165466
# Generation 100 has Chi-Squared: 427.047666
# Generation 200 has Chi-Squared: 421.214944
# Generation 300 has Chi-Squared: 413.319119
# Generation 400 has Chi-Squared: 412.949979
# Generation 500 has Chi-Squared: 412.931191
# Generation 600 has Chi-Squared: 412.916080
# Generation 700 has Chi-Squared: 412.916058
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 4142.008448
# Generation 100 has Chi-Squared: 547.865067
# Generation 200 has Chi-Squared: 509.719002
# Generation 300 has Chi-Squared: 490.589037
# Generation 400 has Chi-Squared: 489.929515
# Generation 500 has Chi-Squared: 489.929497
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 2338.201748
# Generation 100 has Chi-Squared: 483.229486
# Generation 200 has Chi-Squared: 382.281501
# Generation 300 has Chi-Squared: 364.385194
# Generation 400 has Chi-Squared: 364.290060
# Generation 500 has Chi-Squared: 364.190239
# Generation 600 has Chi-Squared: 364.171403
# Generation 700 has Chi-Squared: 364.171085
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 348.446784
# Generation 100 has Chi-Squared: 277.017236
# Generation 200 has Chi-Squared: 276.480239
# Generation 300 has Chi-Squared: 276.380697
# Generation 400 has Chi-Squared: 276.378935
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 1809.690303
# Generation 100 has Chi-Squared: 271.017912
# Generation 200 has Chi-Squared: 254.448701
# Generation 300 has Chi-Squared: 254.429273
# Generation 400 has Chi-Squared: 254.429201
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 250.153593
# Generation 100 has Chi-Squared: 242.636124
# Generation 200 has Chi-Squared: 242.292750
# Generation 300 has Chi-Squared: 242.137367
# Generation 400 has Chi-Squared: 242.111199
# Generation 500 has Chi-Squared: 242.079949
# Generation 600 has Chi-Squared: 242.051110
# Generation 700 has Chi-Squared: 241.974235
# Generation 800 has Chi-Squared: 241.968392
# Generation 900 has Chi-Squared: 241.968068
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 264.509916
# Generation 100 has Chi-Squared: 263.087620
# Generation 200 has Chi-Squared: 263.073586
# Generation 300 has Chi-Squared: 263.070956
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 176.115477
# Generation 100 has Chi-Squared: 176.115477
# Generation 200 has Chi-Squared: 176.115477
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 175.289094
# Generation 100 has Chi-Squared: 175.289094
# Generation 200 has Chi-Squared: 175.289094
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 656.675015
# Generation 100 has Chi-Squared: 285.145664
# Generation 200 has Chi-Squared: 271.073191
# Generation 300 has Chi-Squared: 169.745683
# Generation 400 has Chi-Squared: 168.184474
# Generation 500 has Chi-Squared: 166.486836
# Generation 600 has Chi-Squared: 166.299892
# Generation 700 has Chi-Squared: 166.295448
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 740.057865
# Generation 100 has Chi-Squared: 149.528422
# Generation 200 has Chi-Squared: 136.691032
# Generation 300 has Chi-Squared: 128.365484
# Generation 400 has Chi-Squared: 127.390855
# Generation 500 has Chi-Squared: 125.719025
# Generation 600 has Chi-Squared: 125.406385
# Generation 700 has Chi-Squared: 125.320778
# Generation 800 has Chi-Squared: 125.234931
# Generation 900 has Chi-Squared: 125.227830
# Generation 1000 has Chi-Squared: 125.227029
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 125.951691
# Generation 100 has Chi-Squared: 125.951691
# Generation 200 has Chi-Squared: 125.951691
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 122.162732
# Generation 100 has Chi-Squared: 122.162732
# Generation 200 has Chi-Squared: 122.162732
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 107.341652
# Generation 100 has Chi-Squared: 107.341652
# Generation 200 has Chi-Squared: 107.341652
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 109.647708
# Generation 100 has Chi-Squared: 106.709984
# Generation 200 has Chi-Squared: 106.709050
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 127.823567
# Generation 100 has Chi-Squared: 127.823567
# Generation 200 has Chi-Squared: 127.823567
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 148.123454
# Generation 100 has Chi-Squared: 118.534834
# Generation 200 has Chi-Squared: 118.092413
# Generation 300 has Chi-Squared: 118.064773
# Generation 400 has Chi-Squared: 118.036249
# Generation 500 has Chi-Squared: 118.032637
# Generation 600 has Chi-Squared: 118.005705
# Generation 700 has Chi-Squared: 118.005530
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 135.573717
# Generation 100 has Chi-Squared: 135.573717
# Generation 200 has Chi-Squared: 135.573717
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 454.523485
# Generation 100 has Chi-Squared: 445.682238
# Generation 200 has Chi-Squared: 445.646371
# Generation 300 has Chi-Squared: 445.608189
# Generation 400 has Chi-Squared: 445.596192
# Generation 500 has Chi-Squared: 445.589942
# Generation 600 has Chi-Squared: 445.589372
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 142.645274
# Generation 100 has Chi-Squared: 142.645274
# Generation 200 has Chi-Squared: 142.645274
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 275.597081
# Generation 100 has Chi-Squared: 150.410926
# Generation 200 has Chi-Squared: 140.715072
# Generation 300 has Chi-Squared: 140.565074
# Generation 400 has Chi-Squared: 140.563687
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 198.040737
# Generation 100 has Chi-Squared: 194.003488
# Generation 200 has Chi-Squared: 193.610591
# Generation 300 has Chi-Squared: 193.602962
# Generation 400 has Chi-Squared: 193.602952
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 215.617531
# Generation 100 has Chi-Squared: 215.617531
# Generation 200 has Chi-Squared: 215.617531
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 287.370471
# Generation 100 has Chi-Squared: 280.559597
# Generation 200 has Chi-Squared: 279.826010
# Generation 300 has Chi-Squared: 279.477283
# Generation 400 has Chi-Squared: 279.270509
# Generation 500 has Chi-Squared: 279.260658
# Generation 600 has Chi-Squared: 279.245538
# Generation 700 has Chi-Squared: 279.245538
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 755.111735
# Generation 100 has Chi-Squared: 360.296171
# Generation 200 has Chi-Squared: 344.047552
# Generation 300 has Chi-Squared: 333.961543
# Generation 400 has Chi-Squared: 333.523379
# Generation 500 has Chi-Squared: 333.436578
# Generation 600 has Chi-Squared: 333.153229
# Generation 700 has Chi-Squared: 333.004782
# Generation 800 has Chi-Squared: 332.990274
# Generation 900 has Chi-Squared: 332.955136
# Generation 1000 has Chi-Squared: 332.954519
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 312.018574
# Generation 100 has Chi-Squared: 312.018574
# Generation 200 has Chi-Squared: 312.018574
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 349.108067
# Generation 100 has Chi-Squared: 349.108067
# Generation 200 has Chi-Squared: 349.108067
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 389.427540
# Generation 100 has Chi-Squared: 389.427540
# Generation 200 has Chi-Squared: 389.427540
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 975.010092
# Generation 100 has Chi-Squared: 488.078731
# Generation 200 has Chi-Squared: 434.652994
# Generation 300 has Chi-Squared: 383.028785
# Generation 400 has Chi-Squared: 379.961775
# Generation 500 has Chi-Squared: 377.848402
# Generation 600 has Chi-Squared: 377.372746
# Generation 700 has Chi-Squared: 377.370322
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 417.813200
# Generation 100 has Chi-Squared: 417.551875
# Generation 200 has Chi-Squared: 417.514345
# Generation 300 has Chi-Squared: 417.512578
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 593.274501
# Generation 100 has Chi-Squared: 518.751052
# Generation 200 has Chi-Squared: 515.500983
# Generation 300 has Chi-Squared: 515.076365
# Generation 400 has Chi-Squared: 515.071994
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 573.820156
# Generation 100 has Chi-Squared: 571.383863
# Generation 200 has Chi-Squared: 571.331590
# Generation 300 has Chi-Squared: 571.296844
# Generation 400 has Chi-Squared: 571.290472
# Generation 500 has Chi-Squared: 571.284956
# Generation 600 has Chi-Squared: 571.280946
# Generation 700 has Chi-Squared: 571.278805
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 587.554710
# Generation 100 has Chi-Squared: 579.737970
# Generation 200 has Chi-Squared: 579.700723
# Generation 300 has Chi-Squared: 579.699721
# Generation 400 has Chi-Squared: 579.649871
# Generation 500 has Chi-Squared: 579.588320
# Generation 600 has Chi-Squared: 579.563893
# Generation 700 has Chi-Squared: 579.562922
# Generation 800 has Chi-Squared: 579.554000
# Generation 900 has Chi-Squared: 579.548924
# Generation 1000 has Chi-Squared: 579.546802
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 4509.639664
# Generation 100 has Chi-Squared: 738.392249
# Generation 200 has Chi-Squared: 729.341056
# Generation 300 has Chi-Squared: 702.787634
# Generation 400 has Chi-Squared: 702.532943
# Generation 500 has Chi-Squared: 702.476930
# Generation 600 has Chi-Squared: 702.470045
# Generation 700 has Chi-Squared: 702.468667
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 772.664385
# Generation 100 has Chi-Squared: 753.194603
# Generation 200 has Chi-Squared: 752.612935
# Generation 300 has Chi-Squared: 752.604814
# Generation 400 has Chi-Squared: 752.604235
# Generation 500 has Chi-Squared: 752.431841
# Generation 600 has Chi-Squared: 752.398304
# Generation 700 has Chi-Squared: 752.333329
# Generation 800 has Chi-Squared: 752.313927
# Generation 900 has Chi-Squared: 752.310590
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 6782.019471
# Generation 100 has Chi-Squared: 1081.952465
# Generation 200 has Chi-Squared: 869.768573
# Generation 300 has Chi-Squared: 844.394663
# Generation 400 has Chi-Squared: 832.273931
# Generation 500 has Chi-Squared: 798.066411
# Generation 600 has Chi-Squared: 767.346728
# Generation 700 has Chi-Squared: 767.173075
# Generation 800 has Chi-Squared: 767.168016
# Generation 900 has Chi-Squared: 766.526581
# Generation 1000 has Chi-Squared: 765.564234
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 9751.914933
# Generation 100 has Chi-Squared: 2987.851050
# Generation 200 has Chi-Squared: 944.369439
# Generation 300 has Chi-Squared: 943.127525
# Generation 400 has Chi-Squared: 942.874942
# Generation 500 has Chi-Squared: 942.775309
# Generation 600 has Chi-Squared: 942.280219
# Generation 700 has Chi-Squared: 941.627116
# Generation 800 has Chi-Squared: 941.626853
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 12384.073622
# Generation 100 has Chi-Squared: 1160.912049
# Generation 200 has Chi-Squared: 1120.376812
# Generation 300 has Chi-Squared: 1101.213180
# Generation 400 has Chi-Squared: 1098.700129
# Generation 500 has Chi-Squared: 1098.433967
# Generation 600 has Chi-Squared: 1098.228660
# Generation 700 has Chi-Squared: 1098.216209
# Generation 800 has Chi-Squared: 1098.216001
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 12535.161791
# Generation 100 has Chi-Squared: 1497.998306
# Generation 200 has Chi-Squared: 1452.609605
# Generation 300 has Chi-Squared: 1281.151518
# Generation 400 has Chi-Squared: 1262.476972
# Generation 500 has Chi-Squared: 1259.770460
# Generation 600 has Chi-Squared: 1259.310846
# Generation 700 has Chi-Squared: 1259.082072
# Generation 800 has Chi-Squared: 1258.987054
# Generation 900 has Chi-Squared: 1258.938913
# Generation 1000 has Chi-Squared: 1258.879652
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 12064.259417
# Generation 100 has Chi-Squared: 2268.642856
# Generation 200 has Chi-Squared: 1143.253494
# Generation 300 has Chi-Squared: 1113.010408
# Generation 400 has Chi-Squared: 1109.668833
# Generation 500 has Chi-Squared: 1109.591426
# Generation 600 has Chi-Squared: 1109.586919
# Generation 700 has Chi-Squared: 1109.145819
# Generation 800 has Chi-Squared: 1092.173734
# Generation 900 has Chi-Squared: 987.927577
# Generation 1000 has Chi-Squared: 980.994262
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 14828.042204
# Generation 100 has Chi-Squared: 6693.706433
# Generation 200 has Chi-Squared: 6085.739565
# Generation 300 has Chi-Squared: 5825.116855
# Generation 400 has Chi-Squared: 3982.840798
# Generation 500 has Chi-Squared: 2138.059242
# Generation 600 has Chi-Squared: 1845.482208
# Generation 700 has Chi-Squared: 1828.893867
# Generation 800 has Chi-Squared: 1650.825927
# Generation 900 has Chi-Squared: 1484.699881
# Generation 1000 has Chi-Squared: 1484.382984
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 15235.678289
# Generation 100 has Chi-Squared: 1795.541223
# Generation 200 has Chi-Squared: 1641.918089
# Generation 300 has Chi-Squared: 1638.777793
# Generation 400 has Chi-Squared: 1638.775191
# Generation 500 has Chi-Squared: 1638.772346
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 16372.873560
# Generation 100 has Chi-Squared: 8481.868879
# Generation 200 has Chi-Squared: 3027.379582
# Generation 300 has Chi-Squared: 2211.294761
# Generation 400 has Chi-Squared: 2131.481040
# Generation 500 has Chi-Squared: 1991.640357
# Generation 600 has Chi-Squared: 1967.624286
# Generation 700 has Chi-Squared: 1962.832951
# Generation 800 has Chi-Squared: 1962.515310
# Generation 900 has Chi-Squared: 1962.216569
# Generation 1000 has Chi-Squared: 1962.216091
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 22710.376452
# Generation 100 has Chi-Squared: 4567.505345
# Generation 200 has Chi-Squared: 4537.422471
# Generation 300 has Chi-Squared: 4086.469762
# Generation 400 has Chi-Squared: 3259.114771
# Generation 500 has Chi-Squared: 2443.458325
# Generation 600 has Chi-Squared: 2299.109959
# Generation 700 has Chi-Squared: 2239.418310
# Generation 800 has Chi-Squared: 2229.711484
# Generation 900 has Chi-Squared: 2228.901015
# Generation 1000 has Chi-Squared: 2228.672159
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 11340.381811
# Generation 100 has Chi-Squared: 3296.277066
# Generation 200 has Chi-Squared: 2231.746427
# Generation 300 has Chi-Squared: 2164.623119
# Generation 400 has Chi-Squared: 2161.926702
# Generation 500 has Chi-Squared: 2161.926702
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 31149.300065
# Generation 100 has Chi-Squared: 8544.971122
# Generation 200 has Chi-Squared: 2936.812003
# Generation 300 has Chi-Squared: 2936.278531
# Generation 400 has Chi-Squared: 2936.247823
# Generation 500 has Chi-Squared: 2936.232774
# Generation 600 has Chi-Squared: 2936.213632
# Generation 700 has Chi-Squared: 2936.198321
# Generation 800 has Chi-Squared: 2936.189903
# Generation 900 has Chi-Squared: 2936.189874
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 32136.106862
# Generation 100 has Chi-Squared: 11745.720847
# Generation 200 has Chi-Squared: 5174.127312
# Generation 300 has Chi-Squared: 2482.907034
# Generation 400 has Chi-Squared: 2439.577868
# Generation 500 has Chi-Squared: 2435.229954
# Generation 600 has Chi-Squared: 2434.848076
# Generation 700 has Chi-Squared: 2434.623734
# Generation 800 has Chi-Squared: 2434.577612
# Generation 900 has Chi-Squared: 2434.569460
# Generation 1000 has Chi-Squared: 2434.519206
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 30005.071080
# Generation 100 has Chi-Squared: 6154.060128
# Generation 200 has Chi-Squared: 5361.391318
# Generation 300 has Chi-Squared: 3206.456013
# Generation 400 has Chi-Squared: 2638.233671
# Generation 500 has Chi-Squared: 2537.115284
# Generation 600 has Chi-Squared: 2482.189390
# Generation 700 has Chi-Squared: 2465.474023
# Generation 800 has Chi-Squared: 2458.081884
# Generation 900 has Chi-Squared: 2457.770527
# Generation 1000 has Chi-Squared: 2457.706233
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 21342.972026
# Generation 100 has Chi-Squared: 3704.859152
# Generation 200 has Chi-Squared: 2149.484389
# Generation 300 has Chi-Squared: 2148.137319
# Generation 400 has Chi-Squared: 2147.143222
# Generation 500 has Chi-Squared: 2146.670885
# Generation 600 has Chi-Squared: 2146.611836
# Generation 700 has Chi-Squared: 2146.398725
# Generation 800 has Chi-Squared: 2145.485238
# Generation 900 has Chi-Squared: 2145.433603
# Generation 1000 has Chi-Squared: 2145.433271
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 36859.720860
# Generation 100 has Chi-Squared: 2271.607403
# Generation 200 has Chi-Squared: 2178.595036
# Generation 300 has Chi-Squared: 2165.972385
# Generation 400 has Chi-Squared: 2165.720415
# Generation 500 has Chi-Squared: 2163.750210
# Generation 600 has Chi-Squared: 2163.096188
# Generation 700 has Chi-Squared: 2163.067148
# Generation 800 has Chi-Squared: 2163.052180
# Generation 900 has Chi-Squared: 2163.039340
# Generation 1000 has Chi-Squared: 2163.036634
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")
# Generation 0 has Chi-Squared: 45880.459875
# Generation 100 has Chi-Squared: 4401.354843
# Generation 200 has Chi-Squared: 4369.981611
# Generation 300 has Chi-Squared: 4366.965293
# Generation 400 has Chi-Squared: 4366.694794
# Generation 500 has Chi-Squared: 4365.536673
# Generation 600 has Chi-Squared: 4365.535594
# STOP("ChangeOverGeneration with {'tolerance': 0.005, 'generations': 200}")
# Generation 0 has Chi-Squared: 36352.369761
# Generation 100 has Chi-Squared: 11226.744758
# Generation 200 has Chi-Squared: 7828.965192
# Generation 300 has Chi-Squared: 5002.939331
# Generation 400 has Chi-Squared: 4773.149576
# Generation 500 has Chi-Squared: 4608.774245
# Generation 600 has Chi-Squared: 4331.967951
# Generation 700 has Chi-Squared: 4025.791359
# Generation 800 has Chi-Squared: 3865.576029
# Generation 900 has Chi-Squared: 3860.666694
# Generation 1000 has Chi-Squared: 3859.952967
# STOP("EvaluationLimits with {'evaluations': 60000, 'generations': 1000}")

# %%
for i, aiframe in enumerate(adjusted_intermediate_frames):
    frame = Frame(aiframe.image)
    try:
        image = draw_cube(frame.image, aiframe.create_camera_and_project(cube), wide=2)
        cv2.imwrite("intermediate/{}.png".format("%03d" % i), image)
    except Exception as e:
        print(e)
