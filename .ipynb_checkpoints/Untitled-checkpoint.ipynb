# %%
import cv2
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

import seaborn as sns

from src.camera import Camera
from src.utils.cube import generate_cube

# %%
MATCHER_THREHSOLD = 0.7

# %%
image_1 = cv2.imread('rec3d_0.png')
image_2 = cv2.imread('rec3d_30.png')
image_3 = cv2.imread('rec3d_50.png')

# %%
# match features
sift = cv2.xfeatures2d.SIFT_create()
FLANN_INDEX_KDTREE = 0
index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = 5)
search_params = dict(checks = 50)
flann = cv2.FlannBasedMatcher(index_params, search_params)

kp1, des1 = sift.detectAndCompute(image_1, None)
kp2, des2 = sift.detectAndCompute(image_2, None)
kp3, des3 = sift.detectAndCompute(image_3, None)

matches12 = flann.knnMatch(des1, des2, k=2)
matches13 = flann.knnMatch(des1, des3, k=2)

# %%
# find common query indexes
qidx12 = [m.queryIdx for m,n in list(filter(lambda x: x[0].distance < MATCHER_THREHSOLD*x[1].distance, matches12))]
qidx13 = [m.queryIdx for m,n in list(filter(lambda x: x[0].distance < MATCHER_THREHSOLD*x[1].distance, matches13))]

common_query_indexes = list(set(qidx12).intersection(qidx13))
len(common_query_indexes)
# Out:
# 223

# %%
# match between 3 images
good_12_matches = []
for m, n in matches12:
    if m.queryIdx in common_query_indexes:
        good_12_matches.append(m)

good_13_matches = []
for m, n in matches13:
    if m.queryIdx in common_query_indexes:
        good_13_matches.append(m)


        
pts1 = np.float64([kp1[m.queryIdx].pt for m in good_12_matches]).reshape(-1,1,2)
pts2 = np.float64([kp2[m.trainIdx].pt for m in good_12_matches]).reshape(-1,1,2)
pts3 = np.float64([kp3[m.trainIdx].pt for m in good_13_matches]).reshape(-1,1,2)

# %%
pts1.shape, pts2.shape, pts3.shape
# Out:
# ((223, 1, 2), (223, 1, 2), (223, 1, 2))

# %%
E, mask = cv2.findEssentialMat(
    pts1, 
    pts2, 
    focal=1.0, 
    pp=(486.2, 265.59), 
    method=cv2.RANSAC, 
    prob=0.999, 
    threshold=1.0
)


points, R, t, mask = cv2.recoverPose(
    E, 
    pts1, 
    pts2, 
    focal=1.0,
    pp=(486.2, 265.59),
    mask=mask
)

K, dist = Camera().K, Camera().distortion 

camera1 = Camera.create(np.eye(3, 3), np.zeros((3, 1)))
camera2 = Camera.create(R, t)

undistorted_points_1 = cv2.undistortPoints(pts1, K, dist, R=np.eye(3, 3), P=camera1.get_projection_matrix())
undistorted_points_2 = cv2.undistortPoints(pts2, K, dist, R=R, P=camera2.get_projection_matrix())

points_3d_homog = cv2.triangulatePoints(
    camera1.get_projection_matrix(),
    camera2.get_projection_matrix(),
    undistorted_points_1,
    undistorted_points_2
)
points_3d = cv2.convertPointsFromHomogeneous(points_3d_homog.T)

# %%
# from pyntcloud import PyntCloud
# df_points = pd.DataFrame(points_3d.reshape(points_3d.shape[0], 3), columns=['x', 'y', 'z'])
# colors = (np.random.uniform(size=(points_3d.shape[0], 3)) * 255).astype(np.uint8)
# df_points[['red', 'blue', 'green']] = pd.DataFrame(colors, index=df_points.index)
# cloud = PyntCloud(df_points)
# cloud.plot(point_size=0.05, opacity=0.6, lines=[[[0, 0, 0], [0, 0, 1]]], line_color=[0xFFFFFF])

# %%
plt.imshow(image_1)

# %%
# recover 3rd camera
_, rvecs, tvecs, inliers = cv2.solvePnPRansac(points_3d, pts3, Camera().K, Camera().distortion) 
camera3 = Camera.create(cv2.Rodrigues(rvecs)[0], tvecs)

# %%
# create cube
from src.utils.cube import generate_cube
cube = generate_cube(1.0, [0,0,10])

# %%
for point in camera1.project(cube):
    try:
        x, y = point[0]
        cv2.circle(image_1, (int(x), int(y)), 3, (255, 0, 0), thickness=2, lineType=8, shift=0)
    except Exception as e:
        print(e)
        
plt.imshow(image_1)

# %%
for point in camera2.project(cube):
    try:
        x, y = point[0]
        cv2.circle(image_2, (int(x), int(y)), 3, (255, 0, 0), thickness=2, lineType=8, shift=0)
    except Exception as e:
        print(e)
        
plt.imshow(image_2)

# %%
for point in camera3.project(cube):
    try:
        x, y = point[0]
        cv2.circle(image_3, (int(x), int(y)), 3, (255, 0, 0), thickness=2, lineType=8, shift=0)
    except Exception as e:
        print(e)
        
plt.imshow(image_3)

# %%
# get intermediate frame & get common points
image_intermediate = cv2.imread('rec3d_15.png')
kp_intermediate, des_intermediate = sift.detectAndCompute(image_intermediate, None)
matches1intermediate = flann.knnMatch(des1, des_intermediate, k=2)

good_1_intermediate_matches = []
for m, n in matches1intermediate:
    if m.queryIdx in common_query_indexes:
        good_1_intermediate_matches.append(m)
        
pts_intermediate = np.float64([kp_intermediate[m.trainIdx].pt for m in good_1_intermediate_matches]).reshape(-1,1,2)

# %%
# try to recover intermediate frame
from scipy.optimize import minimize, rosen, rosen_der, basinhopping, fmin, fmin_cg, differential_evolution
from mystic.penalty import quadratic_inequality
from mystic.solvers import diffev2, fmin
from mystic.monitors import VerboseMonitor

def reprojection_distance(input, points_3d, points_2d):
    r1, r2, r3, t1, t2, t3 = input[0], input[1], input[2], input[3], input[4], input[5]
    R = cv2.Rodrigues(np.array([r1, r2, r3]))[0]
    t = np.array([[t1], [t2], [t3]])
    camera = Camera()
    projected = cv2.projectPoints(
        points_3d,
        R,
        t,
        camera.K,
        camera.distortion
    )[0]
    vec1 = projected.reshape(projected.shape[0]*2)
    vec2 = points_2d.reshape(points_2d.shape[0]*2)
    res = 0
    for v1, v2 in zip(vec1, vec2):
        res += pow(v1 - v2, 2)
    return res

# %%
tmp_rod = cv2.Rodrigues(camera2.R)[0]
tmp_tvec = camera2.t
initial = [
    tmp_rod[0],
    tmp_rod[1],
    tmp_rod[2],
    tmp_tvec[0],
    tmp_tvec[1],
    tmp_tvec[2]  
]
initial = [x[0] for x in initial]

upbound = [10. for x in initial]
lbound = [-10 for x in initial]

bnds = [(x, y) for x, y in zip(upbound, lbound)]

mon = VerboseMonitor(100)
result = diffev2(
    reprojection_distance, 
    x0=bnds, 
    args=(points_3d, pts_intermediate),
    npop=10, 
    gtol=200,
    disp=False, 
    full_output=True, 
    itermon=mon, 
    maxiter=900
)

res = result[0]
r1, r2, r3, t1, t2, t3 = res[0], res[1], res[2], res[3], res[4], res[5]
R_intermediate = cv2.Rodrigues(np.array([r1, r2, r3]))[0]
t_intermediate = np.array([[t1], [t2], [t3]])

camera_intermediate = Camera.create(R_intermediate, t_intermediate)
# Out:
# Generation 0 has Chi-Squared: 8716249.299116
# Generation 100 has Chi-Squared: 1870182.804234
# Generation 200 has Chi-Squared: 1869524.518139
# Generation 300 has Chi-Squared: 1869506.763198
# Generation 400 has Chi-Squared: 1869057.873595
# Generation 500 has Chi-Squared: 1868541.288812
# Generation 600 has Chi-Squared: 1867813.133646
# Generation 700 has Chi-Squared: 1867636.877637
# Generation 800 has Chi-Squared: 1867419.058413
# Generation 900 has Chi-Squared: 1867388.917668
# STOP("EvaluationLimits with {'generations': 900, 'evaluations': 60000}")

# %%
image_intermediate = cv2.imread('rec3d_15.png')
for point in camera_intermediate.project(cube):
    try:
        x, y = point[0]
        cv2.circle(image_intermediate, (int(x), int(y)), 3, (255, 0, 0), thickness=2, lineType=8, shift=0)
    except Exception as e:
        print(e)
        
plt.imshow(image_intermediate)

# %%
from keras.layers import Input, Dense, Dropout
from keras.models import Model

# %%
# this is our input placeholder
input_img = Input(shape=(3,))
encoded = Dense(150, activation='relu')(input_img)
encoded = Dropout(0.3)(encoded)
encoded = Dense(64, activation='relu')(encoded)
encoded = Dropout(0.3)(encoded)
encoded = Dense(32, activation='relu')(encoded)

decoded = Dense(32, activation='relu')(encoded)
decoded = Dropout(0.3)(decoded)
decoded = Dense(16, activation='relu')(decoded)
decoded = Dropout(0.3)(decoded)
decoded = Dense(2, activation='relu')(decoded)
autoencoder = Model(input_img, decoded)

autoencoder.compile(optimizer='adagrad', loss='mean_squared_error')

# %%
from sklearn.model_selection import train_test_split

X = points_3d.reshape((points_3d.shape[0], 3))
y = pts_intermediate.reshape((pts_intermediate.shape[0], 2))
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
autoencoder.fit(x_train, y_train,
                epochs=100,
                batch_size=30,
                shuffle=True,
                validation_data=(x_test, y_test))
# Out:
# Train on 149 samples, validate on 74 samples
# Epoch 1/100
# 149/149 [==============================] - 0s - loss: 27386.6623 - val_loss: 138936.8482
# Epoch 2/100
# 149/149 [==============================] - 0s - loss: 17519.0994 - val_loss: 135106.4959
# Epoch 3/100
# 149/149 [==============================] - 0s - loss: 26714.1366 - val_loss: 134435.2441
# Epoch 4/100
# 149/149 [==============================] - 0s - loss: 23922.1067 - val_loss: 136605.5639
# Epoch 5/100
# 149/149 [==============================] - 0s - loss: 24894.8677 - val_loss: 140973.7460
# Epoch 6/100
# 149/149 [==============================] - 0s - loss: 22680.1959 - val_loss: 139410.8957
# Epoch 7/100
# 149/149 [==============================] - 0s - loss: 21107.0983 - val_loss: 137568.7755
# Epoch 8/100
# 149/149 [==============================] - 0s - loss: 22158.1749 - val_loss: 133378.6824
# Epoch 9/100
# 149/149 [==============================] - 0s - loss: 21703.6486 - val_loss: 133622.4301
# Epoch 10/100
# 149/149 [==============================] - 0s - loss: 20039.8014 - val_loss: 128500.4419
# Epoch 11/100
# 149/149 [==============================] - 0s - loss: 22512.2273 - val_loss: 124509.1676
# Epoch 12/100
# 149/149 [==============================] - 0s - loss: 21415.1172 - val_loss: 123363.4909
# Epoch 13/100
# 149/149 [==============================] - 0s - loss: 18801.2719 - val_loss: 127683.0002
# Epoch 14/100
# 149/149 [==============================] - 0s - loss: 22518.1092 - val_loss: 130150.3750
# Epoch 15/100
# 149/149 [==============================] - 0s - loss: 21125.4029 - val_loss: 133660.4783
# Epoch 16/100
# 149/149 [==============================] - 0s - loss: 25973.3027 - val_loss: 136788.2409
# Epoch 17/100
# 149/149 [==============================] - 0s - loss: 22696.0473 - val_loss: 136492.9853
# Epoch 18/100
# 149/149 [==============================] - 0s - loss: 19607.7060 - val_loss: 143002.9290
# Epoch 19/100
# 149/149 [==============================] - 0s - loss: 21127.8754 - val_loss: 146606.2432
# Epoch 20/100
# 149/149 [==============================] - 0s - loss: 19143.4601 - val_loss: 143808.6720
# Epoch 21/100
# 149/149 [==============================] - 0s - loss: 19827.1831 - val_loss: 145140.8163
# Epoch 22/100
# 149/149 [==============================] - 0s - loss: 18187.3765 - val_loss: 145107.6995
# Epoch 23/100
# 149/149 [==============================] - 0s - loss: 20681.2615 - val_loss: 144876.0243
# Epoch 24/100
# 149/149 [==============================] - 0s - loss: 20140.9794 - val_loss: 143705.8675
# Epoch 25/100
# 149/149 [==============================] - 0s - loss: 23922.8613 - val_loss: 147418.3656
# Epoch 26/100
# 149/149 [==============================] - 0s - loss: 26712.7032 - val_loss: 140553.5992
# Epoch 27/100
# 149/149 [==============================] - 0s - loss: 20496.7780 - val_loss: 131826.6764
# Epoch 28/100
# 149/149 [==============================] - 0s - loss: 20628.3141 - val_loss: 134713.7704
# Epoch 29/100
# 149/149 [==============================] - 0s - loss: 20068.1411 - val_loss: 138555.0842
# Epoch 30/100
# 149/149 [==============================] - 0s - loss: 20011.4574 - val_loss: 134253.0842
# Epoch 31/100
# 149/149 [==============================] - 0s - loss: 17893.1293 - val_loss: 133858.0913
# Epoch 32/100
# 149/149 [==============================] - 0s - loss: 17593.4950 - val_loss: 136551.2033
# Epoch 33/100
# 149/149 [==============================] - 0s - loss: 20993.7893 - val_loss: 129747.6149
# Epoch 34/100
# 149/149 [==============================] - 0s - loss: 20828.3503 - val_loss: 131318.4105
# Epoch 35/100
# 149/149 [==============================] - 0s - loss: 24004.1415 - val_loss: 138225.6202
# Epoch 36/100
# 149/149 [==============================] - 0s - loss: 18864.6994 - val_loss: 143413.0326
# Epoch 37/100
# 149/149 [==============================] - 0s - loss: 19855.8240 - val_loss: 139055.6637
# Epoch 38/100
# 149/149 [==============================] - 0s - loss: 22687.6147 - val_loss: 135575.0062
# Epoch 39/100
# 149/149 [==============================] - 0s - loss: 18237.7540 - val_loss: 130953.4813
# Epoch 40/100
# 149/149 [==============================] - 0s - loss: 20108.3742 - val_loss: 129856.8837
# Epoch 41/100
# 149/149 [==============================] - 0s - loss: 17926.9331 - val_loss: 135661.7216
# Epoch 42/100
# 149/149 [==============================] - 0s - loss: 20862.1726 - val_loss: 132704.5228
# Epoch 43/100
# 149/149 [==============================] - 0s - loss: 24367.2552 - val_loss: 130701.3972
# Epoch 44/100
# 149/149 [==============================] - 0s - loss: 19857.9384 - val_loss: 132368.1178
# Epoch 45/100
# 149/149 [==============================] - 0s - loss: 19773.5001 - val_loss: 140350.8035
# Epoch 46/100
# 149/149 [==============================] - 0s - loss: 21823.1540 - val_loss: 133028.8492
# Epoch 47/100
# 149/149 [==============================] - 0s - loss: 22684.6188 - val_loss: 140764.5067
# Epoch 48/100
# 149/149 [==============================] - 0s - loss: 18842.3345 - val_loss: 144981.0049
# Epoch 49/100
# 149/149 [==============================] - 0s - loss: 21246.4497 - val_loss: 148495.3640
# Epoch 50/100
# 149/149 [==============================] - 0s - loss: 19646.0307 - val_loss: 147808.5471
# Epoch 51/100
# 149/149 [==============================] - 0s - loss: 20996.6089 - val_loss: 151950.7627
# Epoch 52/100
# 149/149 [==============================] - 0s - loss: 21100.8449 - val_loss: 153765.5731
# Epoch 53/100
# 149/149 [==============================] - 0s - loss: 21527.1913 - val_loss: 150193.1862
# Epoch 54/100
# 149/149 [==============================] - 0s - loss: 19691.4577 - val_loss: 149577.1395
# Epoch 55/100
# 149/149 [==============================] - 0s - loss: 22790.9879 - val_loss: 149992.5483
# Epoch 56/100
# 149/149 [==============================] - 0s - loss: 21585.1554 - val_loss: 143723.3981
# Epoch 57/100
# 149/149 [==============================] - 0s - loss: 20201.5009 - val_loss: 140369.1089
# Epoch 58/100
# 149/149 [==============================] - 0s - loss: 23002.8704 - val_loss: 141873.7315
# Epoch 59/100
# 149/149 [==============================] - 0s - loss: 19639.9844 - val_loss: 138514.6612
# Epoch 60/100
# 149/149 [==============================] - 0s - loss: 27488.6261 - val_loss: 126793.6937
# Epoch 61/100
# 149/149 [==============================] - 0s - loss: 20053.6142 - val_loss: 129055.4604
# Epoch 62/100
# 149/149 [==============================] - 0s - loss: 23922.1379 - val_loss: 133679.5732
# Epoch 63/100
# 149/149 [==============================] - 0s - loss: 20861.9257 - val_loss: 134070.5303
# Epoch 64/100
# 149/149 [==============================] - 0s - loss: 20276.9721 - val_loss: 137312.5670
# Epoch 65/100
# 149/149 [==============================] - 0s - loss: 23679.6867 - val_loss: 143367.3697
# Epoch 66/100
# 149/149 [==============================] - 0s - loss: 20410.6003 - val_loss: 145628.4613
# Epoch 67/100
# 149/149 [==============================] - 0s - loss: 18295.2459 - val_loss: 136205.6505
# Epoch 68/100
# 149/149 [==============================] - 0s - loss: 22784.3872 - val_loss: 139962.6536
# Epoch 69/100
# 149/149 [==============================] - 0s - loss: 22329.7682 - val_loss: 141277.0731
# Epoch 70/100
# 149/149 [==============================] - 0s - loss: 22021.3234 - val_loss: 138751.9036
# Epoch 71/100
# 149/149 [==============================] - 0s - loss: 18857.1742 - val_loss: 144236.6180
# Epoch 72/100
# 149/149 [==============================] - 0s - loss: 20696.4828 - val_loss: 140330.5804
# Epoch 73/100
# 149/149 [==============================] - 0s - loss: 19414.1942 - val_loss: 137601.6476
# Epoch 74/100
# 149/149 [==============================] - 0s - loss: 19454.7494 - val_loss: 136024.9094
# Epoch 75/100
# 149/149 [==============================] - 0s - loss: 15495.2932 - val_loss: 137085.0272
# Epoch 76/100
# 149/149 [==============================] - 0s - loss: 26486.7408 - val_loss: 135442.9494
# Epoch 77/100
# 149/149 [==============================] - 0s - loss: 22917.1987 - val_loss: 137996.3554
# Epoch 78/100
# 149/149 [==============================] - 0s - loss: 19896.1995 - val_loss: 138932.4136
# Epoch 79/100
# 149/149 [==============================] - 0s - loss: 19102.7767 - val_loss: 140463.0069
# Epoch 80/100
# 149/149 [==============================] - 0s - loss: 22030.5857 - val_loss: 139599.5831
# Epoch 81/100
# 149/149 [==============================] - 0s - loss: 23992.1141 - val_loss: 137192.8499
# Epoch 82/100
# 149/149 [==============================] - 0s - loss: 20839.2213 - val_loss: 134906.2114
# Epoch 83/100
# 149/149 [==============================] - 0s - loss: 23092.1937 - val_loss: 136938.8834
# Epoch 84/100
# 149/149 [==============================] - 0s - loss: 18810.1159 - val_loss: 139573.9152
# Epoch 85/100
# 149/149 [==============================] - 0s - loss: 17323.0655 - val_loss: 137092.9877
# Epoch 86/100
# 149/149 [==============================] - 0s - loss: 24021.1168 - val_loss: 139599.8149
# Epoch 87/100
# 149/149 [==============================] - 0s - loss: 21293.6044 - val_loss: 143518.6829
# Epoch 88/100
# 149/149 [==============================] - 0s - loss: 23851.0250 - val_loss: 144990.4104
# Epoch 89/100
# 149/149 [==============================] - 0s - loss: 23191.1920 - val_loss: 145168.1279
# Epoch 90/100
# 149/149 [==============================] - 0s - loss: 22238.3329 - val_loss: 149847.0749
# Epoch 91/100
# 149/149 [==============================] - 0s - loss: 24912.4604 - val_loss: 146397.9718
# Epoch 92/100
# 149/149 [==============================] - 0s - loss: 22254.1219 - val_loss: 141854.9701
# Epoch 93/100
# 149/149 [==============================] - 0s - loss: 21784.8895 - val_loss: 143761.8610
# Epoch 94/100
# 149/149 [==============================] - 0s - loss: 21532.2242 - val_loss: 148260.9318
# Epoch 95/100
# 149/149 [==============================] - 0s - loss: 20299.2852 - val_loss: 154799.7459
# Epoch 96/100
# 149/149 [==============================] - 0s - loss: 17963.0935 - val_loss: 157313.9441
# Epoch 97/100
# 149/149 [==============================] - 0s - loss: 22127.1259 - val_loss: 147879.4953
# Epoch 98/100
# 149/149 [==============================] - 0s - loss: 21279.4908 - val_loss: 150007.3203
# Epoch 99/100
# 149/149 [==============================] - 0s - loss: 19623.5695 - val_loss: 151823.5494
# Epoch 100/100
# 149/149 [==============================] - 0s - loss: 22239.2854 - val_loss: 159939.4045

# %%
autoencoder.predict(cube)
# Out:
# array([[ 152.02304077,   52.95981979],
#        [ 209.11987305,   72.69651794],
#        [ 224.56890869,   79.22737122],
#        [ 168.0872345 ,   59.67994308],
#        [ 178.29693604,   62.21872711],
#        [ 235.52716064,   82.00666809],
#        [ 251.02044678,   88.54099274],
#        [ 194.5112915 ,   68.98521423]], dtype=float32)

# %%
image_intermediate = cv2.imread('rec3d_15.png')
for point in list(autoencoder.predict(cube)):
    try:
        x, y = point
        cv2.circle(image_intermediate, (int(x), int(y)), 3, (255, 0, 0), thickness=2, lineType=8, shift=0)
    except Exception as e:
        print(e)
        
plt.imshow(image_intermediate)
